# %%
import math
def today(day):
    today= 'Today is ' + day + "."
    return today

print(today('Monday'))
print(today('the third'))
print(today('June 27th'))

def multiply(x, e):
    multiply=x*e
    return multiply
    
print(multiply(math.pi, math.e))
print(multiply(525600,365))
print(multiply (2222231,3333312))
# Out:
# Today is Monday.
# Today is the third.
# Today is June 27th.
# 8.539734222673566
# 191844000
# 7407389259072
